# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.petersen_graph()
subax1 = plt.subplot(121)
nx.draw(G, with_labels=True, font_weight='bold')
subax2 = plt.subplot(122)
nx.draw_shell(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt


G = nx.Graph()
dataset = []

# 逐行读取文件并处理内容后写入新的文件
with open('tqy.txt', 'r') as infile:
    for line in infile:
        data = line.strip().split(';')
        
        dataset.append(data)

        G.add_edge(data[0], data[1])
# Set a constant weight value for all edges (e.g., 1.0)
for u, v in G.edges():
    G[u][v]['weight'] = 1.0

# Use Kamada-Kawai layout algorithm to adjust node positions
pos = nx.kamada_kawai_layout(G)

# Enlarge the size of the plot
plt.figure(figsize=(12, 10))

# Draw the directed graph with arrows representing edge direction
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=2000, font_size=10, font_weight='bold', connectionstyle='arc3,rad=0.2', arrows=True, edge_color=[d['weight'] for u, v, d in G.edges(data=True)], edge_cmap=plt.cm.Reds)

plt.show()

print(type(dataset[0]))
# Out:
# <class 'list'>

# %%
import networkx as nx
import matplotlib.pyplot as plt




G = nx.Graph()

G.add_edge(1, 2)


nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, font_size=10, font_weight='bold')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()
dataset = []

# 逐行读取文件并处理内容后写入新的文件
with open('tqy.txt', 'r') as infile:
    for line in infile:
        data = line.strip().split(';')
        dataset.append(data)
        G.add_edge(data[0], data[1])

# Use Kamada-Kawai layout algorithm to adjust node positions
pos = nx.kamada_kawai_layout(G)

# Enlarge the size of the plot
plt.figure(figsize=(12, 10))

# Draw the undirected graph with arrows representing edge direction
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=2000, font_size=10, font_weight='bold', connectionstyle='arc3,rad=0.2', edge_color='red', arrows=False, edgecolors='k')

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()
dataset = []

# readin File
with open('tqy2.txt', 'r') as infile:
    for line in infile:
        data = line.strip().split(';')
        dataset.append(data)
        G.add_edge(data[0], data[1])

# Use Kamada-Kawai layout algorithm to adjust node positions
pos = nx.kamada_kawai_layout(G)

# Enlarge the size of the plot
plt.figure(figsize=(12, 10))

# Draw the undirected graph with arrows representing edge direction
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=2000, font_size=10, font_weight='bold', connectionstyle='arc3,rad=0.2', edge_color='red', arrows=True, edgecolors='k')

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()
dataset = []

# readin Fil
with open('tqy5.txt', 'r') as infile:
    for line in infile:
        data = line.strip().split(';')
        dataset.append(data)
        G.add_edge(data[0], data[1])

# Use Kamada-Kawai layout algorithm to adjust node positions
pos = nx.kamada_kawai_layout(G)

# Enlarge the size of the plot
plt.figure(figsize=(12, 10))

# Draw the undirected graph with arrows representing edge direction
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=2000, font_size=10, font_weight='bold', connectionstyle='arc3,rad=0.2', edge_color='red', arrows=True, edgecolors='k')

plt.show()

# %%
import matplotlib.pyplot as plt
def collectM(file):
    
zero=0
one=0
two=0
three=0
four=0
five=0
six=0
seven=0
eight=0
nine=0
with open('messageRecord.txt', 'r') as infile:
    for line in infile:
        data = line.strip().split(',')
        agentNum =int(data[0][-1])
        if agentNum == 0:
            zero += 1
        if agentNum == 1:
            one += 1
        if agentNum == 2:
            two += 1
        if agentNum == 3:
            three += 1
        if agentNum == 4:
            four += 1
        if agentNum == 5:
            five += 1
        if agentNum == 6:
            six += 1
        if agentNum == 7:
            seven += 1
        if agentNum == 8:
            eight += 1
        if agentNum == 9:
            nine += 1
receive_data = {
    'Agent0': zero,
    'Agent1': one,
    'Agent2': two,
    'Agent3': three,
    'Agent4': four,
    'Agent5': five,
    'Agent6': six,
    'Agent7': seven,
    'Agent8': eight,
}

zero=0
one=0
two=0
three=0
four=0
five=0
six=0
seven=0
eight=0
nine=0
with open('messageRecord.txt', 'r') as infile:
    for line in infile:
        data = line.strip().split(',')
        
        agentNum = int(data[1][-1])
        if agentNum == 0:
            zero += 1
        if agentNum == 1:
            one += 1
        if agentNum == 2:
            two += 1
        if agentNum == 3:
            three += 1
        if agentNum == 4:
            four += 1
        if agentNum == 5:
            five += 1
        if agentNum == 6:
            six += 1
        if agentNum == 7:
            seven += 1
        if agentNum == 8:
            eight += 1
        if agentNum == 9:
            nine += 1
send_data = {
    'Agent0': zero,
    'Agent1': one,
    'Agent2': two,
    'Agent3': three,
    'Agent4': four,
    'Agent5': five,
    'Agent6': six,
    'Agent7': seven,
    'Agent8': eight,
    'Agent9': nine,
}

# Extracting Agent name and reception count data
agents = list(receive_data.keys())
receive_counts = list(receive_data.values())

send_counts = list(send_data.values())

bar_width = 0.35

fig, ax = plt.subplots()


bar1 = ax.bar(agents, receive_counts, bar_width, label='Received', color='skyblue')
bar2 = ax.bar(agents, send_counts, bar_width, label='Sent', color='orange', bottom=receive_counts)

ax.legend()

ax.set_xlabel('Agent')
ax.set_ylabel('Counts')
ax.set_title('Cumulative Counts of Agent Receiving and Sending')


plt.tight_layout()
plt.show()
# Out:
# 9 6
